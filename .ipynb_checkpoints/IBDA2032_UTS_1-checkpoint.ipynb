# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Importing the dataset
ump_data = pd.read_csv("salary.csv")
ump_data
# Out:
#              REGION   SALARY  YEAR
# 0              ACEH   128000  1997
# 1    SUMATERA UTARA   151000  1997
# 2    SUMATERA BARAT   119000  1997
# 3              RIAU   151500  1997
# 4             JAMBI   119500  1997
# ..              ...      ...   ...
# 865          MALUKU  2619312  2022
# 866    MALUKU UTARA  2862231  2022
# 867     PAPUA BARAT  3200000  2022
# 868           PAPUA  3561932  2022
# 869       INDONESIA  2644709  2022
#
# [870 rows x 3 columns]

# %%
# Split the data into training and testing sets
train_data, test_data = train_test_split(ump_data, test_size=0.2, random_state=42)

# %%
# Train a linear regression model for each region using the training data
models = {}
for region in train_data['REGION'].unique():
    X_train = train_data.loc[train_data['REGION'] == region]['YEAR'].values.reshape(-1, 1)
    y_train = train_data.loc[train_data['REGION'] == region]['SALARY'].values.reshape(-1, 1)
    model = LinearRegression().fit(X_train, y_train)
    models[region] = model
    
models

# Evaluate the models on the test data and print the prediction score for each model
for region in test_data['REGION'].unique():
    X_test = test_data.loc[test_data['REGION'] == region]['YEAR'].values.reshape(-1, 1)
    y_test = test_data.loc[test_data['REGION'] == region]['SALARY'].values.reshape(-1, 1)
    model = models[region]
    score = model.score(X_test, y_test)
    print(f"Region {region}, prediction score = {score}")
# Out:
# Region KEP. BANGKA BELITUNG, prediction score = 0.8974995712066577
# Region BENGKULU, prediction score = 0.8201756884898136
# Region LAMPUNG, prediction score = 0.12753731046009276
# Region KALIMANTAN TENGAH, prediction score = 0.9754999525014382
# Region ACEH, prediction score = 0.8789029695129059
# Region SULAWESI TENGGARA, prediction score = 0.46495270882807416
# Region RIAU, prediction score = 0.9244560155774424
# Region BANTEN, prediction score = 0.9881252742263511
# Region DI YOGYAKARTA, prediction score = 0.872120608571257
# Region SULAWESI UTARA, prediction score = 0.8574217478269823
# Region JAMBI, prediction score = 0.7362686327084091
# Region BALI, prediction score = 0.9136413683986894
# Region MALUKU, prediction score = 0.9397082466551514
# Region KALIMANTAN TIMUR, prediction score = 0.5538440475870896
# Region SUMATERA SELATAN, prediction score = -1.3816185998431116
# Region SUMATERA BARAT, prediction score = 0.8684265043283965
# Region SULAWESI SELATAN, prediction score = 0.8836377746718251
# Region JAWA TENGAH, prediction score = -2.1424398801877316
# Region PAPUA, prediction score = 0.9440609733089094
# Region JAWA BARAT, prediction score = 0.8720338140344328
# Region KALIMANTAN SELATAN, prediction score = 0.9453059490126143
# Region SULAWESI TENGAH, prediction score = 0.9257955617970851
# Region MALUKU UTARA, prediction score = 0.9864232624429111
# Region INDONESIA, prediction score = 0.8308155801228396
# Region SUMATERA UTARA, prediction score = 0.9449436490775587
# Region DKI JAKARTA, prediction score = 0.9082908367420018
# Region PAPUA BARAT, prediction score = 0.9572536346245233
# Region KALIMANTAN UTARA, prediction score = 0.8840695753683219
# Region KALIMANTAN BARAT, prediction score = 0.9087590087993985
# Region NUSA TENGGARA BARAT, prediction score = 0.9799663278982362
# Region NUSA TENGGARA TIMUR, prediction score = 0.9642104978905796
# Region SULAWESI BARAT, prediction score = 0.9695762554607885
# Region GORONTALO, prediction score = 0.6817878765239942
# Region JAWA TIMUR, prediction score = 0.8577496668430462
# Region KEP. RIAU, prediction score = -0.8112328195907743

# %%
regions = ump_data['REGION'].unique()
n_regions = len(regions)
n_rows = (n_regions + 1) // 2 # Round up to the nearest integer
n_cols = 2
fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(15, 5 * n_rows))

for i, region in enumerate(regions):
    row = i // n_cols
    col = i % n_cols
    X = ump_data.loc[ump_data['REGION'] == region]['YEAR'].values.reshape(-1, 1)
    y = ump_data.loc[ump_data['REGION'] == region]['SALARY'].values.reshape(-1, 1)
    model = models[region]
    y_pred = model.predict(X)
    
    ax = axs[row, col]
    ax.scatter(X, y)
    ax.plot(X, y_pred, color='red')
    ax.set_title(f"{region} Salary vs Year")
    ax.set_xlabel("Year")
    ax.set_ylabel("Salary")
    
plt.tight_layout()
plt.show()

# %%
# generates an array of future years
future_years = np.array(range(ump_data['YEAR'].max() + 1, ump_data['YEAR'].max() + 24))
future_ump = []
for provinsi in ump_data['REGION'].unique():
    model = models[provinsi]
    future_ump_provinsi = model.predict(future_years.reshape(-1, 1)) # use model to predict the salary for each year
    future_ump.extend(future_ump_provinsi)
display(future_years)
display(future_ump)
# Out:
# array([2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033,
#        2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044,
#        2045])
# [array([3113319.13425308]),
#  array([3242861.99461749]),
#  array([3372404.8549819]),
#  array([3501947.71534628]),
#  array([3631490.57571068]),
#  array([3761033.43607509]),
#  array([3890576.2964395]),
#  array([4020119.15680391]),
#  array([4149662.01716828]),
#  array([4279204.87753269]),
#  array([4408747.7378971]),
#  array([4538290.59826151]),
#  array([4667833.45862591]),
#  array([4797376.31899029]),
#  array([4926919.1793547]),
#  array([5056462.0397191]),
#  array([5186004.90008351]),
#  array([5315547.76044792]),
#  array([5445090.6208123]),
#  array([5574633.4811767]),
#  array([5704176.34154111]),
#  array([5833719.20190552]),
#  array([5963262.06226993]),
#  array([2472057.91678691]),
#  array([2571947.28498217]),
#  array([2671836.65317747]),
#  array([2771726.02137274]),
#  array([2871615.38956803]),
#  array([2971504.7577633]),
#  array([3071394.12595856]),
#  array([3171283.49415386]),
#  array([3271172.86234912]),
#  array([3371062.23054442]),
#  array([3470951.59873968]),
#  array([3570840.96693495]),
#  array([3670730.33513024]),
#  array([3770619.70332551]),
#  array([3870509.07152081]),
#  array([3970398.43971607]),
#  array([4070287.80791134]),
#  array([4170177.17610663]),
#  array([4270066.5443019]),
#  array([4369955.91249719]),
#  array([4469845.28069246]),
#  array([4569734.64888772]),
#  array([4669624.01708302]),
#  array([2559287.63522983]),
#  array([2665236.42984176]),
#  array([2771185.22445366]),
#  array([2877134.01906556]),
#  array([2983082.81367746]),
#  array([3089031.60828936]),
#  array([3194980.40290129]),
#  array([3300929.19751319]),
#  array([3406877.99212509]),
#  array([3512826.78673699]),
#  array([3618775.5813489]),
#  array([3724724.3759608]),
#  array([3830673.17057273]),
#  array([3936621.96518463]),
#  array([4042570.75979653]),
#  array([4148519.55440843]),
#  array([4254468.34902033]),
#  array([4360417.14363226]),
#  array([4466365.93824416]),
#  array([4572314.73285607]),
#  array([4678263.52746797]),
#  array([4784212.32207987]),
#  array([4890161.11669177]),
#  array([2934158.75987083]),
#  array([3059399.24804667]),
#  array([3184639.73622251]),
#  array([3309880.22439837]),
#  array([3435120.71257421]),
#  array([3560361.20075008]),
#  array([3685601.68892592]),
#  array([3810842.17710176]),
#  array([3936082.66527763]),
#  array([4061323.15345347]),
#  array([4186563.64162934]),
#  array([4311804.12980518]),
#  array([4437044.61798105]),
#  array([4562285.10615689]),
#  array([4687525.59433272]),
#  array([4812766.08250859]),
#  array([4938006.57068443]),
#  array([5063247.0588603]),
#  array([5188487.54703614]),
#  array([5313728.03521198]),
#  array([5438968.52338785]),
#  array([5564209.01156369]),
#  array([5689449.49973956]),
#  array([2764976.60400128]),
#  array([2883184.35238031]),
#  array([3001392.10075936]),
#  array([3119599.84913841]),
#  array([3237807.59751746]),
#  array([3356015.34589648]),
#  array([3474223.09427553]),
#  array([3592430.84265459]),
#  array([3710638.59103364]),
#  array([3828846.33941266]),
#  array([3947054.08779171]),
#  array([4065261.83617076]),
#  array([4183469.58454978]),
#  array([4301677.33292884]),
#  array([4419885.08130789]),
#  array([4538092.82968694]),
#  array([4656300.57806596]),
#  array([4774508.32644501]),
#  array([4892716.07482406]),
#  array([5010923.82320312]),
#  array([5129131.57158214]),
#  array([5247339.31996119]),
#  array([5365547.06834024]),
#  array([3235229.16859525]),
#  array([3384457.8872714]),
#  array([3533686.60594749]),
#  array([3682915.32462364]),
#  array([3832144.04329973]),
#  array([3981372.76197588]),
#  array([4130601.48065203]),
#  array([4279830.19932812]),
#  array([4429058.91800427]),
#  array([4578287.63668036]),
#  array([4727516.35535651]),
#  array([4876745.0740326]),
#  array([5025973.79270875]),
#  array([5175202.51138484]),
#  array([5324431.23006099]),
#  array([5473659.94873714]),
#  array([5622888.66741323]),
#  array([5772117.38608938]),
#  array([5921346.10476547]),
#  array([6070574.82344162]),
#  array([6219803.54211771]),
#  array([6369032.26079386]),
#  array([6518260.97946995]),
#  array([2235604.82231539]),
#  array([2328725.98933485]),
#  array([2421847.15635431]),
#  array([2514968.32337376]),
#  array([2608089.49039322]),
#  array([2701210.65741268]),
#  array([2794331.82443213]),
#  array([2887452.99145159]),
#  array([2980574.15847105]),
#  array([3073695.3254905]),
#  array([3166816.49250996]),
#  array([3259937.65952942]),
#  array([3353058.82654887]),
#  array([3446179.99356836]),
#  array([3539301.16058782]),
#  array([3632422.32760727]),
#  array([3725543.49462673]),
#  array([3818664.66164619]),
#  array([3911785.82866564]),
#  array([4004906.9956851]),
#  array([4098028.16270456]),
#  array([4191149.32972401]),
#  array([4284270.49674347]),
#  array([2450119.47479174]),
#  array([2552746.89785182]),
#  array([2655374.32091188]),
#  array([2758001.74397194]),
#  array([2860629.167032]),
#  array([2963256.59009206]),
#  array([3065884.01315212]),
#  array([3168511.43621218]),
#  array([3271138.85927224]),
#  array([3373766.2823323]),
#  array([3476393.70539236]),
#  array([3579021.12845242]),
#  array([3681648.55151248]),
#  array([3784275.97457254]),
#  array([3886903.3976326]),
#  array([3989530.82069266]),
#  array([4092158.24375272]),
#  array([4194785.66681281]),
#  array([4297413.08987287]),
#  array([4400040.51293293]),
#  array([4502667.93599299]),
#  array([4605295.35905305]),
#  array([4707922.78211311]),
#  array([2792777.25555554]),
#  array([2908200.92261207]),
#  array([3023624.5896686]),
#  array([3139048.25672513]),
#  array([3254471.92378166]),
#  array([3369895.59083819]),
#  array([3485319.25789472]),
#  array([3600742.92495126]),
#  array([3716166.59200779]),
#  array([3831590.25906432]),
#  array([3947013.92612085]),
#  array([4062437.59317738]),
#  array([4177861.26023391]),
#  array([4293284.92729044]),
#  array([4408708.59434697]),
#  array([4524132.2614035]),
#  array([4639555.92846003]),
#  array([4754979.59551656]),
#  array([4870403.26257309]),
#  array([4985826.92962962]),
#  array([5101250.59668615]),
#  array([5216674.26374269]),
#  array([5332097.93079922]),
#  array([4305055.85121542]),
#  array([4491930.13076282]),
#  array([4678804.41031015]),
#  array([4865678.68985748]),
#  array([5052552.96940488]),
#  array([5239427.24895221]),
#  array([5426301.5284996]),
#  array([5613175.80804694]),
#  array([5800050.08759433]),
#  array([5986924.36714166]),
#  array([6173798.646689]),
#  array([6360672.92623639]),
#  array([6547547.20578372]),
#  array([6734421.48533112]),
#  array([6921295.76487845]),
#  array([7108170.04442585]),
#  array([7295044.32397318]),
#  array([7481918.60352057]),
#  array([7668792.88306791]),
#  array([7855667.16261524]),
#  array([8042541.44216263]),
#  array([8229415.72170997]),
#  array([8416290.00125736]),
#  array([1942941.55567524]),
#  array([2024255.18859571]),
#  array([2105568.82151619]),
#  array([2186882.45443669]),
#  array([2268196.08735716]),
#  array([2349509.72027764]),
#  array([2430823.35319811]),
#  array([2512136.98611861]),
#  array([2593450.61903909]),
#  array([2674764.25195956]),
#  array([2756077.88488004]),
#  array([2837391.51780054]),
#  array([2918705.15072101]),
#  array([3000018.78364149]),
#  array([3081332.41656196]),
#  array([3162646.04948246]),
#  array([3243959.68240294]),
#  array([3325273.31532341]),
#  array([3406586.94824389]),
#  array([3487900.58116439]),
#  array([3569214.21408486]),
#  array([3650527.84700534]),
#  array([3731841.47992581]),
#  array([1702539.13671476]),
#  array([1773280.45412475]),
#  array([1844021.77153474]),
#  array([1914763.08894473]),
#  array([1985504.40635476]),
#  array([2056245.72376475]),
#  array([2126987.04117474]),
#  array([2197728.35858473]),
#  array([2268469.67599472]),
#  array([2339210.99340475]),
#  array([2409952.31081474]),
#  array([2480693.62822473]),
#  array([2551434.94563472]),
#  array([2622176.26304471]),
#  array([2692917.58045474]),
#  array([2763658.89786473]),
#  array([2834400.21527472]),
#  array([2905141.53268471]),
#  array([2975882.85009474]),
#  array([3046624.16750473]),
#  array([3117365.48491472]),
#  array([3188106.80232471]),
#  array([3258848.1197347]),
#  array([1757901.47626594]),
#  array([1828584.1157271]),
#  array([1899266.75518829]),
#  array([1969949.39464945]),
#  array([2040632.03411064]),
#  array([2111314.6735718]),
#  array([2181997.31303298]),
#  array([2252679.95249414]),
#  array([2323362.59195533]),
#  array([2394045.23141649]),
#  array([2464727.87087765]),
#  array([2535410.51033884]),
#  array([2606093.1498]),
#  array([2676775.78926119]),
#  array([2747458.42872235]),
#  array([2818141.06818354]),
#  array([2888823.7076447]),
#  array([2959506.34710586]),
#  array([3030188.98656705]),
#  array([3100871.62602821]),
#  array([3171554.2654894]),
#  array([3242236.90495056]),
#  array([3312919.54441175]),
#  array([1768423.29612976]),
#  array([1840583.56631693]),
#  array([1912743.8365041]),
#  array([1984904.10669127]),
#  array([2057064.37687844]),
#  array([2129224.64706561]),
#  array([2201384.91725278]),
#  array([2273545.18743995]),
#  array([2345705.45762712]),
#  array([2417865.72781429]),
#  array([2490025.99800146]),
#  array([2562186.26818863]),
#  array([2634346.53837579]),
#  array([2706506.80856296]),
#  array([2778667.07875013]),
#  array([2850827.3489373]),
#  array([2922987.6191245]),
#  array([2995147.88931167]),
#  array([3067308.15949884]),
#  array([3139468.42968601]),
#  array([3211628.69987318]),
#  array([3283788.97006035]),
#  array([3355949.24024752]),
#  array([2338926.93105668]),
#  array([2436254.43492267]),
#  array([2533581.93878865]),
#  array([2630909.44265464]),
#  array([2728236.9465206]),
#  array([2825564.45038658]),
#  array([2922891.95425257]),
#  array([3020219.45811856]),
#  array([3117546.96198452]),
#  array([3214874.4658505]),
#  array([3312201.96971649]),
#  array([3409529.47358248]),
#  array([3506856.97744843]),
#  array([3604184.48131442]),
#  array([3701511.98518041]),
#  array([3798839.48904639]),
#  array([3896166.99291235]),
#  array([3993494.49677834]),
#  array([4090822.00064433]),
#  array([4188149.50451031]),
#  array([4285477.00837627]),
#  array([4382804.51224226]),
#  array([4480132.01610824]),
#  array([2174632.81360164]),
#  array([2265007.38454759]),
#  array([2355381.95549354]),
#  array([2445756.52643949]),
#  array([2536131.09738544]),
#  array([2626505.66833138]),
#  array([2716880.23927733]),
#  array([2807254.81022325]),
#  array([2897629.3811692]),
#  array([2988003.95211515]),
#  array([3078378.5230611]),
#  array([3168753.09400705]),
#  array([3259127.66495299]),
#  array([3349502.23589894]),
#  array([3439876.80684489]),
#  array([3530251.37779084]),
#  array([3620625.94873679]),
#  array([3711000.51968274]),
#  array([3801375.09062868]),
#  array([3891749.6615746]),
#  array([3982124.23252055]),
#  array([4072498.8034665]),
#  array([4162873.37441245]),
#  array([1968190.88745925]),
#  array([2048598.81466469]),
#  array([2129006.74187011]),
#  array([2209414.66907555]),
#  array([2289822.59628096]),
#  array([2370230.52348641]),
#  array([2450638.45069182]),
#  array([2531046.37789726]),
#  array([2611454.30510268]),
#  array([2691862.23230812]),
#  array([2772270.15951353]),
#  array([2852678.08671898]),
#  array([2933086.01392439]),
#  array([3013493.94112983]),
#  array([3093901.86833525]),
#  array([3174309.79554069]),
#  array([3254717.7227461]),
#  array([3335125.64995155]),
#  array([3415533.57715696]),
#  array([3495941.5043624]),
#  array([3576349.43156782]),
#  array([3656757.35877326]),
#  array([3737165.28597867]),
#  array([2336168.17064774]),
#  array([2433255.75101867]),
#  array([2530343.33138961]),
#  array([2627430.91176057]),
#  array([2724518.4921315]),
#  array([2821606.07250243]),
#  array([2918693.6528734]),
#  array([3015781.23324433]),
#  array([3112868.81361526]),
#  array([3209956.39398623]),
#  array([3307043.97435716]),
#  array([3404131.55472809]),
#  array([3501219.13509905]),
#  array([3598306.71546999]),
#  array([3695394.29584092]),
#  array([3792481.87621188]),
#  array([3889569.45658281]),
#  array([3986657.03695375]),
#  array([4083744.61732471]),
#  array([4180832.19769564]),
#  array([4277919.77806658]),
#  array([4375007.35843754]),
#  array([4472094.93880847]),
#  array([2833012.6104829]),
#  array([2951292.27954441]),
#  array([3069571.94860592]),
#  array([3187851.61766747]),
#  array([3306131.28672898]),
#  array([3424410.95579049]),
#  array([3542690.624852]),
#  array([3660970.29391351]),
#  array([3779249.96297505]),
#  array([3897529.63203657]),
#  array([4015809.30109808]),
#  array([4134088.97015959]),
#  array([4252368.6392211]),
#  array([4370648.30828264]),
#  array([4488927.97734416]),
#  array([4607207.64640567]),
#  array([4725487.31546718]),
#  array([4843766.98452869]),
#  array([4962046.65359023]),
#  array([5080326.32265174]),
#  array([5198605.99171326]),
#  array([5316885.66077477]),
#  array([5435165.32983628]),
#  array([2864124.09651285]),
#  array([2986386.09968299]),
#  array([3108648.10285312]),
#  array([3230910.10602325]),
#  array([3353172.10919338]),
#  array([3475434.11236352]),
#  array([3597696.11553365]),
#  array([3719958.11870375]),
#  array([3842220.12187389]),
#  array([3964482.12504402]),
#  array([4086744.12821415]),
#  array([4209006.13138428]),
#  array([4331268.13455442]),
#  array([4453530.13772455]),
#  array([4575792.14089468]),
#  array([4698054.14406481]),
#  array([4820316.14723495]),
#  array([4942578.15040508]),
#  array([5064840.15357521]),
#  array([5187102.15674531]),
#  array([5309364.15991545]),
#  array([5431626.16308558]),
#  array([5553888.16625571]),
#  array([2898568.12220114]),
#  array([3018933.93154651]),
#  array([3139299.74089184]),
#  array([3259665.55023721]),
#  array([3380031.35958257]),
#  array([3500397.16892791]),
#  array([3620762.97827327]),
#  array([3741128.78761861]),
#  array([3861494.59696397]),
#  array([3981860.40630931]),
#  array([4102226.21565467]),
#  array([4222592.02500001]),
#  array([4342957.83434537]),
#  array([4463323.64369071]),
#  array([4583689.45303607]),
#  array([4704055.26238143]),
#  array([4824421.07172677]),
#  array([4944786.88107213]),
#  array([5065152.69041747]),
#  array([5185518.49976283]),
#  array([5305884.30910817]),
#  array([5426250.11845353]),
#  array([5546615.92779887]),
#  array([3314790.9898352]),
#  array([3455378.98908627]),
#  array([3595966.98833728]),
#  array([3736554.98758829]),
#  array([3877142.98683929]),
#  array([4017730.9860903]),
#  array([4158318.98534131]),
#  array([4298906.98459232]),
#  array([4439494.98384339]),
#  array([4580082.98309439]),
#  array([4720670.9823454]),
#  array([4861258.98159641]),
#  array([5001846.98084742]),
#  array([5142434.98009843]),
#  array([5283022.97934943]),
#  array([5423610.9786005]),
#  array([5564198.97785151]),
#  array([5704786.97710252]),
#  array([5845374.97635353]),
#  array([5985962.97560453]),
#  array([6126550.97485554]),
#  array([6267138.97410655]),
#  array([6407726.97335762]),
#  array([2238959.58965459]),
#  array([2332278.48924318]),
#  array([2425597.38883176]),
#  array([2518916.28842035]),
#  array([2612235.18800893]),
#  array([2705554.08759752]),
#  array([2798872.9871861]),
#  array([2892191.88677469]),
#  array([2985510.78636327]),
#  array([3078829.68595186]),
#  array([3172148.58554044]),
#  array([3265467.48512903]),
#  array([3358786.38471761]),
#  array([3452105.2843062]),
#  array([3545424.18389478]),
#  array([3638743.08348337]),
#  array([3732061.98307195]),
#  array([3825380.88266051]),
#  array([3918699.78224909]),
#  array([4012018.68183768]),
#  array([4105337.58142626]),
#  array([4198656.48101485]),
#  array([4291975.38060343]),
#  array([3159227.32587492]),
#  array([3297548.27768219]),
#  array([3435869.22948939]),
#  array([3574190.18129665]),
#  array([3712511.13310385]),
#  array([3850832.08491111]),
#  array([3989153.03671831]),
#  array([4127473.98852557]),
#  array([4265794.94033277]),
#  array([4404115.89213997]),
#  array([4542436.84394723]),
#  array([4680757.79575443]),
#  array([4819078.74756169]),
#  array([4957399.69936889]),
#  array([5095720.65117615]),
#  array([5234041.60298336]),
#  array([5372362.55479062]),
#  array([5510683.50659782]),
#  array([5649004.45840508]),
#  array([5787325.41021228]),
#  array([5925646.36201954]),
#  array([6063967.31382674]),
#  array([6202288.265634]),
#  array([2598006.13217932]),
#  array([2710077.07211065]),
#  array([2822148.01204199]),
#  array([2934218.95197329]),
#  array([3046289.89190462]),
#  array([3158360.83183596]),
#  array([3270431.77176726]),
#  array([3382502.71169859]),
#  array([3494573.65162992]),
#  array([3606644.59156123]),
#  array([3718715.53149256]),
#  array([3830786.47142389]),
#  array([3942857.4113552]),
#  array([4054928.35128653]),
#  array([4166999.29121786]),
#  array([4279070.23114917]),
#  array([4391141.1710805]),
#  array([4503212.11101183]),
#  array([4615283.05094314]),
#  array([4727353.99087447]),
#  array([4839424.9308058]),
#  array([4951495.87073711]),
#  array([5063566.81066844]),
#  array([2600497.71741834]),
#  array([2713992.56185961]),
#  array([2827487.40630087]),
#  array([2940982.25074211]),
#  array([3054477.09518337]),
#  array([3167971.93962461]),
#  array([3281466.78406587]),
#  array([3394961.62850711]),
#  array([3508456.47294837]),
#  array([3621951.31738964]),
#  array([3735446.16183087]),
#  array([3848941.00627214]),
#  array([3962435.85071337]),
#  array([4075930.69515464]),
#  array([4189425.5395959]),
#  array([4302920.38403714]),
#  array([4416415.2284784]),
#  array([4529910.07291964]),
#  array([4643404.9173609]),
#  array([4756899.76180214]),
#  array([4870394.6062434]),
#  array([4983889.45068467]),
#  array([5097384.2951259]),
#  array([3499094.55933708]),
#  array([3642978.85922796]),
#  array([3786863.15911883]),
#  array([3930747.45900971]),
#  array([4074631.75890058]),
#  array([4218516.0587914]),
#  array([4362400.35868227]),
#  array([4506284.65857315]),
#  array([4650168.95846403]),
#  array([4794053.2583549]),
#  array([4937937.55824578]),
#  array([5081821.85813665]),
#  array([5225706.15802753]),
#  array([5369590.45791841]),
#  array([5513474.75780928]),
#  array([5657359.05770016]),
#  array([5801243.35759103]),
#  array([5945127.65748191]),
#  array([6089011.95737278]),
#  array([6232896.25726366]),
#  array([6376780.55715454]),
#  array([6520664.85704541]),
#  array([6664549.15693629]),
#  array([2666401.77263966]),
#  array([2776516.52087346]),
#  array([2886631.26910722]),
#  array([2996746.01734102]),
#  array([3106860.76557481]),
#  array([3216975.51380858]),
#  array([3327090.26204237]),
#  array([3437205.01027614]),
#  array([3547319.75850993]),
#  array([3657434.50674373]),
#  array([3767549.25497749]),
#  array([3877664.00321129]),
#  array([3987778.75144506]),
#  array([4097893.49967885]),
#  array([4208008.24791265]),
#  array([4318122.99614641]),
#  array([4428237.74438021]),
#  array([4538352.49261397]),
#  array([4648467.24084777]),
#  array([4758581.98908153]),
#  array([4868696.73731533]),
#  array([4978811.48554912]),
#  array([5088926.23378289]),
#  array([2955982.80970207]),
#  array([3082119.54812041]),
#  array([3208256.28653875]),
#  array([3334393.02495709]),
#  array([3460529.76337543]),
#  array([3586666.50179377]),
#  array([3712803.24021211]),
#  array([3838939.97863045]),
#  array([3965076.71704879]),
#  array([4091213.45546716]),
#  array([4217350.19388551]),
#  array([4343486.93230385]),
#  array([4469623.67072219]),
#  array([4595760.40914053]),
#  array([4721897.14755887]),
#  array([4848033.88597721]),
#  array([4974170.62439555]),
#  array([5100307.36281389]),
#  array([5226444.10123223]),
#  array([5352580.83965057]),
#  array([5478717.57806894]),
#  array([5604854.31648728]),
#  array([5730991.05490562]),
#  array([2488248.83008248]),
#  array([2591233.10223192]),
#  array([2694217.37438136]),
#  array([2797201.64653081]),
#  array([2900185.91868025]),
#  array([3003170.19082969]),
#  array([3106154.46297914]),
#  array([3209138.73512858]),
#  array([3312123.00727803]),
#  array([3415107.27942747]),
#  array([3518091.55157691]),
#  array([3621075.82372636]),
#  array([3724060.0958758]),
#  array([3827044.36802524]),
#  array([3930028.64017469]),
#  array([4033012.91232413]),
#  array([4135997.18447354]),
#  array([4238981.45662299]),
#  array([4341965.72877243]),
#  array([4444950.00092188]),
#  array([4547934.27307132]),
#  array([4650918.54522076]),
#  array([4753902.81737021]),
#  array([2682053.38604143]),
#  array([2798742.8721374]),
#  array([2915432.35823336]),
#  array([3032121.84432933]),
#  array([3148811.33042529]),
#  array([3265500.81652126]),
#  array([3382190.30261722]),
#  array([3498879.78871319]),
#  array([3615569.27480915]),
#  array([3732258.76090512]),
#  array([3848948.24700108]),
#  array([3965637.73309705]),
#  array([4082327.21919301]),
#  array([4199016.70528898]),
#  array([4315706.19138494]),
#  array([4432395.67748091]),
#  array([4549085.16357687]),
#  array([4665774.64967284]),
#  array([4782464.1357688]),
#  array([4899153.62186477]),
#  array([5015843.10796073]),
#  array([5132532.5940567]),
#  array([5249222.08015266]),
#  array([2653629.17085198]),
#  array([2769649.95467123]),
#  array([2885670.73849049]),
#  array([3001691.52230972]),
#  array([3117712.30612898]),
#  array([3233733.08994824]),
#  array([3349753.8737675]),
#  array([3465774.65758675]),
#  array([3581795.44140598]),
#  array([3697816.22522524]),
#  array([3813837.0090445]),
#  array([3929857.79286376]),
#  array([4045878.57668301]),
#  array([4161899.36050224]),
#  array([4277920.1443215]),
#  array([4393940.92814076]),
#  array([4509961.71196002]),
#  array([4625982.49577928]),
#  array([4742003.2795985]),
#  array([4858024.06341776]),
#  array([4974044.84723702]),
#  array([5090065.63105628]),
#  array([5206086.41487554]),
#  array([2921174.44400001]),
#  array([3068563.15999997]),
#  array([3215951.87599999]),
#  array([3363340.59200001]),
#  array([3510729.30799997]),
#  array([3658118.02399999]),
#  array([3805506.74000001]),
#  array([3952895.45599997]),
#  array([4100284.17199999]),
#  array([4247672.88800001]),
#  array([4395061.60399997]),
#  array([4542450.31999999]),
#  array([4689839.03599995]),
#  array([4837227.75199997]),
#  array([4984616.46799999]),
#  array([5132005.18399996]),
#  array([5279393.89999998]),
#  array([5426782.616]),
#  array([5574171.33199996]),
#  array([5721560.04799998]),
#  array([5868948.764]),
#  array([6016337.47999996]),
#  array([6163726.19599998]),
#  array([3428617.46376806]),
#  array([3586718.95400125]),
#  array([3744820.44423437]),
#  array([3902921.93446749]),
#  array([4061023.42470068]),
#  array([4219124.9149338]),
#  array([4377226.40516692]),
#  array([4535327.89540011]),
#  array([4693429.38563323]),
#  array([4851530.87586635]),
#  array([5009632.36609954]),
#  array([5167733.85633266]),
#  array([5325835.34656578]),
#  array([5483936.83679897]),
#  array([5642038.32703209]),
#  array([5800139.81726521]),
#  array([5958241.3074984]),
#  array([6116342.79773152]),
#  array([6274444.2879647]),
#  array([6432545.77819782]),
#  array([6590647.26843095]),
#  array([6748748.75866413]),
#  array([6906850.24889725]),
#  array([3292135.42352945]),
#  array([3447450.18823534]),
#  array([3602764.95294118]),
#  array([3758079.71764708]),
#  array([3913394.48235297]),
#  array([4068709.24705887]),
#  array([4224024.01176471]),
#  array([4379338.7764706]),
#  array([4534653.5411765]),
#  array([4689968.30588239]),
#  array([4845283.07058829]),
#  array([5000597.83529413]),
#  array([5155912.60000002]),
#  array([5311227.36470592]),
#  array([5466542.12941182]),
#  array([5621856.89411765]),
#  array([5777171.65882355]),
#  array([5932486.42352945]),
#  array([6087801.18823534]),
#  array([6243115.95294118]),
#  array([6398430.71764708]),
#  array([6553745.48235297]),
#  array([6709060.24705887])]

# %%
# create dataframe and insert the predicted data to dataframe
future_df = pd.DataFrame({
    'REGION': np.repeat(ump_data['REGION'].unique(), 23),
    'YEAR': np.tile(range(ump_data['YEAR'].max() + 1, ump_data['YEAR'].max() + 24), ump_data['REGION'].nunique()),
    'SALARY': future_ump
})
future_df
# Out:
#                REGION  YEAR                SALARY
# 0                ACEH  2023  [3113319.1342530847]
# 1                ACEH  2024   [3242861.994617492]
# 2                ACEH  2025  [3372404.8549818993]
# 3                ACEH  2026  [3501947.7153462768]
# 4                ACEH  2027   [3631490.575710684]
# ..                ...   ...                   ...
# 800  KALIMANTAN UTARA  2041  [6087801.1882353425]
# 801  KALIMANTAN UTARA  2042   [6243115.952941179]
# 802  KALIMANTAN UTARA  2043   [6398430.717647076]
# 803  KALIMANTAN UTARA  2044   [6553745.482352972]
# 804  KALIMANTAN UTARA  2045   [6709060.247058868]
#
# [805 rows x 3 columns]

# %%
# change the list on salary column into integer datatype
future_df['SALARY'] = future_df['SALARY'].astype(int)
future_df
# Out:
#                REGION  YEAR   SALARY
# 0                ACEH  2023  3113319
# 1                ACEH  2024  3242861
# 2                ACEH  2025  3372404
# 3                ACEH  2026  3501947
# 4                ACEH  2027  3631490
# ..                ...   ...      ...
# 800  KALIMANTAN UTARA  2041  6087801
# 801  KALIMANTAN UTARA  2042  6243115
# 802  KALIMANTAN UTARA  2043  6398430
# 803  KALIMANTAN UTARA  2044  6553745
# 804  KALIMANTAN UTARA  2045  6709060
#
# [805 rows x 3 columns]

# %%
# combined the original data with the future data
combined_df = pd.concat([ump_data, future_df],axis=0,ignore_index=True)
combined_df
# Out:
#                 REGION   SALARY  YEAR
# 0                 ACEH   128000  1997
# 1       SUMATERA UTARA   151000  1997
# 2       SUMATERA BARAT   119000  1997
# 3                 RIAU   151500  1997
# 4                JAMBI   119500  1997
# ...                ...      ...   ...
# 1670  KALIMANTAN UTARA  6087801  2041
# 1671  KALIMANTAN UTARA  6243115  2042
# 1672  KALIMANTAN UTARA  6398430  2043
# 1673  KALIMANTAN UTARA  6553745  2044
# 1674  KALIMANTAN UTARA  6709060  2045
#
# [1675 rows x 3 columns]

# %%
AVG = combined_df.sort_values(by='YEAR', ascending=True)

AVG['Growth'] = [0] + [AVG['SALARY'].iloc[i] - AVG['SALARY'].iloc[i-1] for i in range(1, len(AVG))]

plt.figure(figsize=(15,12))
plt.title("Average salary growth from 2022 - 2045", size=20, pad=20)

AVG_filtered = AVG.query('YEAR >= 2022 and YEAR <= 2045')

ax = sns.barplot(x='YEAR', y='Growth', data=AVG_filtered, color='green', edgecolor="black")

# loop through each bar and annotate
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 10),
                textcoords = 'offset points')
                
plt.show()

# %%
sns.catplot(x='YEAR', y='SALARY', data=combined_df, kind='point', aspect=5)

# %%
# shows salary growth using barchart
import plotly.express as px

fig = px.bar(combined_df, x='REGION', y="SALARY",color="REGION",
  animation_frame="YEAR", range_y=[0,9000000])
fig.show()

# %%
# Filter data for the last year
latest_year = combined_df['YEAR'].max()
combined_df_latest_year = combined_df[combined_df['YEAR'] == latest_year]

# Take 5 regions with the highest salary
top_5_regions = combined_df_latest_year.groupby('REGION')['SALARY'].max().sort_values(ascending=False)[:5]
top_5_regions = top_5_regions.reset_index()

# Displays 5 regions based on the highest salary
plt.figure(figsize = (16, 8))
graph = sns.barplot(x = 'REGION', y = 'SALARY', data=top_5_regions, order=top_5_regions['REGION'])
graph.set_xticklabels(graph.get_xticklabels(),rotation=45)
plt.xlabel('Region', fontsize=15)
plt.ylabel('Salary', fontsize=15)
plt.title('Top 5 Regions with the Highest Salary', fontsize=20)

for index, row in top_5_regions.iterrows():
    graph.annotate(format(int(row['SALARY']), ','),
                   (row.name, row['SALARY']),
                   ha = 'center', va = 'center',
                   xytext = (0, 10),
                   textcoords = 'offset points')
